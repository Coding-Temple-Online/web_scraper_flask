# %%
from selenium import webdriver
import requests

import pandas
import numpy as np
from bs4 import BeautifulSoup

# %%
# BeautifulSoup4
page = requests.get('https://www.nbastuffer.com/2021-2022-nba-player-stats/')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
tbody = soup.find('tbody', class_='row-hover')

# %%
type(tbody)
# Out:
# bs4.element.Tag

# %%
[type(tr) for tr in tbody]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
# ...

# %%
[i for i in tbody.children]
# Out:
# ['\n',
#  <tr class="row-2 even">
#  <td class="column-1"></td><td class="column-2">Precious Achiuwa</td><td class="column-3">Tor</td><td class="column-4">F</td><td class="column-5">22.25</td><td class="column-6">22</td><td class="column-7">26.3</td><td class="column-8">54.8</td><td class="column-9">17.6</td><td class="column-10">10.6</td><td class="column-11">36</td><td class="column-12">0.528</td><td class="column-13">168</td><td class="column-14">0.423</td><td class="column-15">28</td><td class="column-16">0.286</td><td class="column-17">0.423</td><td class="column-18">0.437</td><td class="column-19">8.4</td><td class="column-20">8.1</td><td class="column-21">16.6</td><td class="column-22">1.5</td><td class="column-23">8.2</td><td class="column-24">0.55</td><td class="column-25">0.55</td><td class="column-26">1.14</td><td class="column-27">7.1</td><td class="column-28">97.4</td><td class="column-29">101.4</td>
#  </tr>,
#  '\n',
#  <tr class="row-3 odd">
# ...

# %%
tr_rows = [tr for idx, tr in enumerate(tbody) if idx%2!=0]

# %%
# # IMPORTANT! GONNA USE LATER!!
# for tr in tr_rows:
#     for td in list(tr.children)[2:-1]:
#         print(td.text)
#         break
#     break
# Out:
# Precious Achiuwa

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.nbastuffer.com')
